# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#parse int parametresini ekleyerek datetime bileşeninin tipini object'ten datetime'a çevirmiş oluruz.
dt = pd.read_csv("GlobalLandTemperaturesByCity.csv" , parse_dates = ["dt"])

# %%
dt.dtypes
# Out:
# dt                               datetime64[ns]
# AverageTemperature                      float64
# AverageTemperatureUncertainty           float64
# City                                     object
# Country                                  object
# Latitude                                 object
# Longitude                                object
# dtype: object

# %%
dt.shape
# Out:
# (8599212, 7)

# %%
dt.head()
# Out:
#           dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0 1743-11-01               6.068                          1.737  Århus
# 1 1743-12-01                 NaN                            NaN  Århus
# 2 1744-01-01                 NaN                            NaN  Århus
# 3 1744-02-01                 NaN                            NaN  Århus
# 4 1744-03-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
# 2  Denmark   57.05N    10.33E
# 3  Denmark   57.05N    10.33E
# 4  Denmark   57.05N    10.33E

# %%
dt.tail(6)
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty    City  \
# 8599206 2013-04-01               7.710                          0.182  Zwolle
# 8599207 2013-05-01              11.464                          0.236  Zwolle
# 8599208 2013-06-01              15.043                          0.261  Zwolle
# 8599209 2013-07-01              18.775                          0.193  Zwolle
# 8599210 2013-08-01              18.025                          0.298  Zwolle
# 8599211 2013-09-01                 NaN                            NaN  Zwolle
#
#              Country Latitude Longitude
# 8599206  Netherlands   52.24N     5.26E
# 8599207  Netherlands   52.24N     5.26E
# 8599208  Netherlands   52.24N     5.26E
# 8599209  Netherlands   52.24N     5.26E
# 8599210  Netherlands   52.24N     5.26E
# 8599211  Netherlands   52.24N     5.26E

# %%
dt.dtypes
# Out:
# dt                               datetime64[ns]
# AverageTemperature                      float64
# AverageTemperatureUncertainty           float64
# City                                     object
# Country                                  object
# Latitude                                 object
# Longitude                                object
# dtype: object

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8599212 entries, 0 to 8599211
# Data columns (total 7 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   dt                             datetime64[ns]
#  1   AverageTemperature             float64
#  2   AverageTemperatureUncertainty  float64
#  3   City                           object
#  4   Country                        object
#  5   Latitude                       object
#  6   Longitude                      object
# dtypes: datetime64[ns](1), float64(2), object(4)
# memory usage: 459.2+ MB

# %%
#sayısal hesaplamaları yapmak için kullanılır. Fakat verilerde outlier varsa değerler sapabilir , dikkat edilmesi gerekir.
dt.describe()
# Out:
#        AverageTemperature  AverageTemperatureUncertainty
# count        8.235082e+06                   8.235082e+06
# mean         1.672743e+01                   1.028575e+00
# std          1.035344e+01                   1.129733e+00
# min         -4.270400e+01                   3.400000e-02
# 25%          1.029900e+01                   3.370000e-01
# 50%          1.883100e+01                   5.910000e-01
# 75%          2.521000e+01                   1.349000e+00
# max          3.965100e+01                   1.539600e+01

# %%
#Büyük boyutlu verileri daha efektif kullanmak için pickle veya parquet formatına çevirebiliriz.
dt.to_pickle("data.pickle")

# %%
dt.to_parquet("data.parquet")

# %%
#veri setindeki kayıp verilerin var olup olmadığını ifade eder. True ise orada kayıp değer var demektir.isnull da kullanılabilir.
dt.isna()
# Out:
#             dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0        False               False                          False  False
# 1        False                True                           True  False
# 2        False                True                           True  False
# 3        False                True                           True  False
# 4        False                True                           True  False
# ...        ...                 ...                            ...    ...
# 8599207  False               False                          False  False
# 8599208  False               False                          False  False
# 8599209  False               False                          False  False
# 8599210  False               False                          False  False
# 8599211  False                True                           True  False
#
#          Country  Latitude  Longitude
# 0          False     False      False
# ...

# %%
dt.isnull()
# Out:
#             dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0        False               False                          False  False
# 1        False                True                           True  False
# 2        False                True                           True  False
# 3        False                True                           True  False
# 4        False                True                           True  False
# ...        ...                 ...                            ...    ...
# 8599207  False               False                          False  False
# 8599208  False               False                          False  False
# 8599209  False               False                          False  False
# 8599210  False               False                          False  False
# 8599211  False                True                           True  False
#
#          Country  Latitude  Longitude
# 0          False     False      False
# ...

# %%
#Her bir kolondaki toplam kayıp data'yı gösterir. 
dt.isna().sum()
# Out:
# dt                                    0
# AverageTemperature               364130
# AverageTemperatureUncertainty    364130
# City                                  0
# Country                               0
# Latitude                              0
# Longitude                             0
# dtype: int64

# %%
dt.isnull().sum()
# Out:
# dt                                    0
# AverageTemperature               364130
# AverageTemperatureUncertainty    364130
# City                                  0
# Country                               0
# Latitude                              0
# Longitude                             0
# dtype: int64

# %%
#verideki toplam kayıp data sayısını gösterir.
dt.isna().sum().sum()
# Out:
# 728260

# %%
#Kolonlara göre data kaybını hesaplar.
dt.isna().sum() / dt.shape[0] * 100
# Out:
# dt                               0.000000
# AverageTemperature               4.234458
# AverageTemperatureUncertainty    4.234458
# City                             0.000000
# Country                          0.000000
# Latitude                         0.000000
# Longitude                        0.000000
# dtype: float64

# %%
#Veri kayıplarından kurtulmak için dropna kullanılır.
dt.dropna()
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty    City  \
# 0       1743-11-01               6.068                          1.737   Århus
# 5       1744-04-01               5.788                          3.624   Århus
# 6       1744-05-01              10.644                          1.283   Århus
# 7       1744-06-01              14.051                          1.347   Århus
# 8       1744-07-01              16.082                          1.396   Århus
# ...            ...                 ...                            ...     ...
# 8599206 2013-04-01               7.710                          0.182  Zwolle
# 8599207 2013-05-01              11.464                          0.236  Zwolle
# 8599208 2013-06-01              15.043                          0.261  Zwolle
# 8599209 2013-07-01              18.775                          0.193  Zwolle
# 8599210 2013-08-01              18.025                          0.298  Zwolle
#
# ...

# %%
'''dropna işleminden sonra boyutta kalıcı değişiklik olmamasının sebebi yukarıda sonucun 
yeni bir data frame olarak dönmesinden kaynaklanır.'''
dt.shape
# Out:
# (8599212, 7)

# %%
#dropna işlemini bri data olarak çalıştırırsak kalıcı olarak değişiklik yapacaktır ve boyut azalacaktır. 
dt1 = dt.dropna()

# %%
dt1.shape
# Out:
# (8235082, 7)

# %%
dt.shape
# Out:
# (8599212, 7)

# %%
#Bir diğer yöntem inplace parametresi ile sağlanır.
dt.dropna(inplace=True)

# %%
dt.shape
# Out:
# (8235082, 7)

# %%
#Kolondan silme işlemi yapar. (0 yazılırsa satırdan) 
dt.dropna(axis=1)
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty    City  \
# 0       1743-11-01               6.068                          1.737   Århus
# 5       1744-04-01               5.788                          3.624   Århus
# 6       1744-05-01              10.644                          1.283   Århus
# 7       1744-06-01              14.051                          1.347   Århus
# 8       1744-07-01              16.082                          1.396   Århus
# ...            ...                 ...                            ...     ...
# 8599206 2013-04-01               7.710                          0.182  Zwolle
# 8599207 2013-05-01              11.464                          0.236  Zwolle
# 8599208 2013-06-01              15.043                          0.261  Zwolle
# 8599209 2013-07-01              18.775                          0.193  Zwolle
# 8599210 2013-08-01              18.025                          0.298  Zwolle
#
# ...

# %%
dt.dropna(axis=0)
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty    City  \
# 0       1743-11-01               6.068                          1.737   Århus
# 5       1744-04-01               5.788                          3.624   Århus
# 6       1744-05-01              10.644                          1.283   Århus
# 7       1744-06-01              14.051                          1.347   Århus
# 8       1744-07-01              16.082                          1.396   Århus
# ...            ...                 ...                            ...     ...
# 8599206 2013-04-01               7.710                          0.182  Zwolle
# 8599207 2013-05-01              11.464                          0.236  Zwolle
# 8599208 2013-06-01              15.043                          0.261  Zwolle
# 8599209 2013-07-01              18.775                          0.193  Zwolle
# 8599210 2013-08-01              18.025                          0.298  Zwolle
#
# ...

# %%
#Eğer satırdaki değerlerin hespi null ise o satırı/sutunu kaldırır.
#(how=any ise bir tanesi bile null olursa o satırı/sutunu kaldırır.)
dt.dropna(axis=0,how="all")
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty    City  \
# 0       1743-11-01               6.068                          1.737   Århus
# 5       1744-04-01               5.788                          3.624   Århus
# 6       1744-05-01              10.644                          1.283   Århus
# 7       1744-06-01              14.051                          1.347   Århus
# 8       1744-07-01              16.082                          1.396   Århus
# ...            ...                 ...                            ...     ...
# 8599206 2013-04-01               7.710                          0.182  Zwolle
# 8599207 2013-05-01              11.464                          0.236  Zwolle
# 8599208 2013-06-01              15.043                          0.261  Zwolle
# 8599209 2013-07-01              18.775                          0.193  Zwolle
# 8599210 2013-08-01              18.025                          0.298  Zwolle
#
# ...

# %%
dt.shape
# Out:
# (8235082, 7)

# %%
dt.isnull().sum()
# Out:
# dt                               0
# AverageTemperature               0
# AverageTemperatureUncertainty    0
# City                             0
# Country                          0
# Latitude                         0
# Longitude                        0
# dtype: int64

# %%
dt1.isnull().sum()
# Out:
# dt                               0
# AverageTemperature               0
# AverageTemperatureUncertainty    0
# City                             0
# Country                          0
# Latitude                         0
# Longitude                        0
# dtype: int64

# %%
dt1.head()
# Out:
#           dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0 1743-11-01               6.068                          1.737  Århus
# 5 1744-04-01               5.788                          3.624  Århus
# 6 1744-05-01              10.644                          1.283  Århus
# 7 1744-06-01              14.051                          1.347  Århus
# 8 1744-07-01              16.082                          1.396  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 5  Denmark   57.05N    10.33E
# 6  Denmark   57.05N    10.33E
# 7  Denmark   57.05N    10.33E
# 8  Denmark   57.05N    10.33E

# %%
dt1["City"]
# Out:
# 0           Århus
# 5           Århus
# 6           Århus
# 7           Århus
# 8           Århus
#             ...
# 8599206    Zwolle
# 8599207    Zwolle
# 8599208    Zwolle
# 8599209    Zwolle
# 8599210    Zwolle
# Name: City, Length: 8235082, dtype: object

# %%
#Çıktıyı data frame olarak gösterir.
dt1[["City"]]
# Out:
#            City
# 0         Århus
# 5         Århus
# 6         Århus
# 7         Århus
# 8         Århus
# ...         ...
# 8599206  Zwolle
# 8599207  Zwolle
# 8599208  Zwolle
# 8599209  Zwolle
# 8599210  Zwolle
#
# [8235082 rows x 1 columns]

# %%
type(dt1[["Country"]])
# Out:
# pandas.core.frame.DataFrame

# %%
dt1["City"].value_counts()
# Out:
# Springfield    9147
# Worcester      8158
# León           7298
# Rongcheng      6385
# Brest          6332
#                ...
# Chosica        1521
# Lima           1521
# Chiclayo       1509
# Trujillo       1491
# Chimbote       1491
# Name: City, Length: 3448, dtype: int64

# %%
dt1[["City" , "Country"]]
# Out:
#            City      Country
# 0         Århus      Denmark
# 5         Århus      Denmark
# 6         Århus      Denmark
# 7         Århus      Denmark
# 8         Århus      Denmark
# ...         ...          ...
# 8599206  Zwolle  Netherlands
# 8599207  Zwolle  Netherlands
# 8599208  Zwolle  Netherlands
# 8599209  Zwolle  Netherlands
# 8599210  Zwolle  Netherlands
#
# [8235082 rows x 2 columns]

# %%
dt1["Country"].shape
# Out:
# (8235082,)

# %%
dt["Country"] =="Turkey"
# Out:
# 0          False
# 5          False
# 6          False
# 7          False
# 8          False
#            ...
# 8599206    False
# 8599207    False
# 8599208    False
# 8599209    False
# 8599210    False
# Name: Country, Length: 8235082, dtype: bool

# %%
dt1[dt1["Country"] == "Turkey"]
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 3239    1743-11-01              10.013                          2.291
# 3244    1744-04-01              13.685                          2.162
# 3245    1744-05-01              15.021                          1.824
# 3246    1744-06-01              19.663                          1.701
# 3247    1744-07-01              22.314                          1.648
# ...            ...                 ...                            ...
# 8585429 2013-04-01              11.876                          0.293
# 8585430 2013-05-01              17.662                          0.196
# 8585431 2013-06-01              19.818                          0.344
# 8585432 2013-07-01              21.343                          0.288
# 8585433 2013-08-01              22.225                          0.454
#
#               City Country Latitude Longitude
# 3239         Çorlu  Turkey   40.99N    27.69E
# ...

# %%
dt1[(dt1["Country"] == "Turkey") | (dt1["Country"] == "Brazil")]
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 3239    1743-11-01              10.013                          2.291
# 3244    1744-04-01              13.685                          2.162
# 3245    1744-05-01              15.021                          1.824
# 3246    1744-06-01              19.663                          1.701
# 3247    1744-07-01              22.314                          1.648
# ...            ...                 ...                            ...
# 8585429 2013-04-01              11.876                          0.293
# 8585430 2013-05-01              17.662                          0.196
# 8585431 2013-06-01              19.818                          0.344
# 8585432 2013-07-01              21.343                          0.288
# 8585433 2013-08-01              22.225                          0.454
#
#               City Country Latitude Longitude
# 3239         Çorlu  Turkey   40.99N    27.69E
# ...

# %%
dt1[(dt1["Country"] == "Turkey") & (dt1["Country"] == "Brazil")]
# Out:
# Empty DataFrame
# Columns: [dt, AverageTemperature, AverageTemperatureUncertainty, City, Country, Latitude, Longitude]
# Index: []

# %%
dt1[(data1["Country"] == "Turkey") & (dt1["AverageTemperature"] > 20)]
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 3247    1744-07-01              22.314                          1.648
# 3318    1750-06-01              20.183                          1.685
# 3319    1750-07-01              24.420                          1.603
# 3320    1750-08-01              23.217                          1.692
# 3330    1751-06-01              21.248                          1.740
# ...            ...                 ...                            ...
# 8585419 2012-06-01              20.797                          0.353
# 8585420 2012-07-01              23.516                          0.298
# 8585421 2012-08-01              21.869                          0.767
# 8585432 2013-07-01              21.343                          0.288
# 8585433 2013-08-01              22.225                          0.454
#
#               City Country Latitude Longitude
# 3247         Çorlu  Turkey   40.99N    27.69E
# ...

# %%
#daha kolay bir şekilde istediğimiz ülkeleri seçmak için isin kullanılabilir. 
dt1[dt1["Country"].isin(["Turkey","Brazil","Denmark"])]
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1743-11-01               6.068                          1.737
# 5       1744-04-01               5.788                          3.624
# 6       1744-05-01              10.644                          1.283
# 7       1744-06-01              14.051                          1.347
# 8       1744-07-01              16.082                          1.396
# ...            ...                 ...                            ...
# 8585429 2013-04-01              11.876                          0.293
# 8585430 2013-05-01              17.662                          0.196
# 8585431 2013-06-01              19.818                          0.344
# 8585432 2013-07-01              21.343                          0.288
# 8585433 2013-08-01              22.225                          0.454
#
#               City  Country Latitude Longitude
# 0            Århus  Denmark   57.05N    10.33E
# ...

# %%
dt_selected = dt1[dt1["Country"].isin(["Turkey","Brazil","Denmark"])]

# %%
dt_selected["Country"].value_counts()
# Out:
# Brazil     451645
# Turkey     147086
# Denmark     12664
# Name: Country, dtype: int64

# %%
dt_selected.shape
# Out:
# (611395, 7)

# %%
dt_selected
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1743-11-01               6.068                          1.737
# 5       1744-04-01               5.788                          3.624
# 6       1744-05-01              10.644                          1.283
# 7       1744-06-01              14.051                          1.347
# 8       1744-07-01              16.082                          1.396
# ...            ...                 ...                            ...
# 8585429 2013-04-01              11.876                          0.293
# 8585430 2013-05-01              17.662                          0.196
# 8585431 2013-06-01              19.818                          0.344
# 8585432 2013-07-01              21.343                          0.288
# 8585433 2013-08-01              22.225                          0.454
#
#               City  Country Latitude Longitude
# 0            Århus  Denmark   57.05N    10.33E
# ...

# %%
#Country'ye göre gruplama yaparak kolonların ort. değeri hesaplanır.
dt_selected.groupby(by="Country").mean()
# Out:
#          AverageTemperature  AverageTemperatureUncertainty
# Country
# Brazil            21.902763                       0.869764
# Denmark            7.802640                       1.656450
# Turkey            12.951888                       1.275864

# %%
dt_selected.groupby("Country").max()
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# Country
# Brazil  2013-08-01              30.495                          5.277
# Denmark 2013-08-01              21.437                         15.396
# Turkey  2013-08-01              32.885                          9.237
#
#                     City Latitude Longitude
# Country
# Brazil   Várzea Paulista    8.84S    67.91W
# Denmark            Århus   57.05N    11.34E
# Turkey             Çorum   42.59N    42.71E

# %%
dt_selected.groupby("Country").agg(["min","max","mean"])
# Out:
#         AverageTemperature                    AverageTemperatureUncertainty  \
#                        min     max       mean                           min
# Country
# Brazil               9.591  30.495  21.902763                         0.040
# Denmark             -7.816  21.437   7.802640                         0.077
# Turkey             -15.353  32.885  12.951888                         0.056
#
#
#             max      mean
# Country
# Brazil    5.277  0.869764
# Denmark  15.396  1.656450
# Turkey    9.237  1.275864

# %%
dt_selected[dt_selected["Country"] == "Turkey"]["AverageTemperature"]
# Out:
# 3239       10.013
# 3244       13.685
# 3245       15.021
# 3246       19.663
# 3247       22.314
#             ...
# 8585429    11.876
# 8585430    17.662
# 8585431    19.818
# 8585432    21.343
# 8585433    22.225
# Name: AverageTemperature, Length: 147086, dtype: float64

# %%
tr_avg_temp = dt_selected[dt_selected["Country"]=="Turkey"]["AverageTemperature"]
br_avg_temp = dt_selected[dt_selected["Country"]=="Brazil"]["AverageTemperature"]

# %%
tr_avg_temp
# Out:
# 3239       10.013
# 3244       13.685
# 3245       15.021
# 3246       19.663
# 3247       22.314
#             ...
# 8585429    11.876
# 8585430    17.662
# 8585431    19.818
# 8585432    21.343
# 8585433    22.225
# Name: AverageTemperature, Length: 147086, dtype: float64

# %%
#ayrık bir dağılım grafiği oluşturur.
sns.displot(tr_avg_temp)
sns.displot(br_avg_temp)

# %%
dt_selected["Country"].value_counts().index
# Out:
# Index(['Brazil', 'Turkey', 'Denmark'], dtype='object')

# %%
dt_selected["Country"].unique()
# Out:
# array(['Denmark', 'Turkey', 'Brazil'], dtype=object)

# %%
#Her ülke için ayrı ayrı grafik çizmek yerine dor döngüsü ile aynı işlemi daha pratik yapabiliriz.
sns.set_style("whitegrid")
plt.figure(figsize=(15,5))
ulkeler = dt_selected["Country"].unique()

# %%
color = ["blue","orange","green"]
for color, ulke in zip(color,ulkeler):
    data = dt_selected[dt_selected["Country"] == ulke]["AverageTemperature"]
    sns.distplot(data)
    ulke_mean = dt_selected[dt_selected["Country"] == ulke]["AverageTemperature"].mean()
    plt.vlines(ulke_mean , 0 , 0.16 , colors=color) 
plt.legend(ulkeler)
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ...

# %%
dt.columns
# Out:
# Index(['dt', 'AverageTemperature', 'AverageTemperatureUncertainty', 'City',
#        'Country', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
dt_selected.columns[1:2]
# Out:
# Index(['AverageTemperature'], dtype='object')

# %%
cols = data_selected.columns[1:3]

# %%
ulkeler = dt_selected["Country"].unique()
for col in cols:
    plt.figure(figsize=(15,5))
    for ulke in ulkeler:
        sns.distplot(dt_selected[dt_selected["Country"] == ulke][col])
    plt.show()
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ...

# %%
dt_selected.head()
# Out:
#           dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0 1743-11-01               6.068                          1.737  Århus
# 5 1744-04-01               5.788                          3.624  Århus
# 6 1744-05-01              10.644                          1.283  Århus
# 7 1744-06-01              14.051                          1.347  Århus
# 8 1744-07-01              16.082                          1.396  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 5  Denmark   57.05N    10.33E
# 6  Denmark   57.05N    10.33E
# 7  Denmark   57.05N    10.33E
# 8  Denmark   57.05N    10.33E

# %%
tr_data = dt_selected[(data_selected["Country"] == "Turkey") & ( data_selected["dt"] > "01.01.2000")]

# %%
tr_data.head()
# Out:
#              dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 6314 2000-02-01               5.691                          0.247  Çorlu
# 6315 2000-03-01               7.236                          0.312  Çorlu
# 6316 2000-04-01              14.052                          0.182  Çorlu
# 6317 2000-05-01              16.821                          0.389  Çorlu
# 6318 2000-06-01              20.860                          0.381  Çorlu
#
#      Country Latitude Longitude
# 6314  Turkey   40.99N    27.69E
# 6315  Turkey   40.99N    27.69E
# 6316  Turkey   40.99N    27.69E
# 6317  Turkey   40.99N    27.69E
# 6318  Turkey   40.99N    27.69E

# %%
#hue parametresi ile görselleştirme yapılır.
plt.figure(figsize=(15,5))
sns.scatterplot(x="dt" , y="AverageTemperature" , data=tr_data , hue="AverageTemperature")
# Out:
# <AxesSubplot:xlabel='dt', ylabel='AverageTemperature'>

# %%
#yıllara göre ortalama bulmak için 
tr_data.groupby(tr_data["dt"].dt.to_period("Y")).mean()
# Out:
#       AverageTemperature  AverageTemperatureUncertainty
# dt
# 2000           14.729162                       0.364453
# 2001           14.580743                       0.375420
# 2002           13.726090                       0.420351
# 2003           13.650212                       0.373575
# 2004           13.684871                       0.334753
# 2005           13.753832                       0.351077
# 2006           13.718907                       0.398644
# 2007           14.232376                       0.364946
# 2008           14.081989                       0.422498
# 2009           14.194766                       0.369637
# 2010           15.483237                       0.438613
# 2011           13.278969                       0.414487
# 2012           14.221969                       0.496595
# 2013           15.345507                       0.488733

# %%
tr_data_means = tr_data.groupby(tr_data["dt"].dt.to_period("Y")).mean()

# %%
tr_data_means
# Out:
#       AverageTemperature  AverageTemperatureUncertainty
# dt
# 2000           14.729162                       0.364453
# 2001           14.580743                       0.375420
# 2002           13.726090                       0.420351
# 2003           13.650212                       0.373575
# 2004           13.684871                       0.334753
# 2005           13.753832                       0.351077
# 2006           13.718907                       0.398644
# 2007           14.232376                       0.364946
# 2008           14.081989                       0.422498
# 2009           14.194766                       0.369637
# 2010           15.483237                       0.438613
# 2011           13.278969                       0.414487
# 2012           14.221969                       0.496595
# 2013           15.345507                       0.488733

# %%
#dt artık index olarak atandığı için tekrar kolon olmasını sağlamnak için index sıfırlanır.
tr_data_means = tr_data.reset_index()

# %%
tr_data_means
# Out:
#         index         dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0        6314 2000-02-01               5.691                          0.247
# 1        6315 2000-03-01               7.236                          0.312
# 2        6316 2000-04-01              14.052                          0.182
# 3        6317 2000-05-01              16.821                          0.389
# 4        6318 2000-06-01              20.860                          0.381
# ...       ...        ...                 ...                            ...
# 8308  8585429 2013-04-01              11.876                          0.293
# 8309  8585430 2013-05-01              17.662                          0.196
# 8310  8585431 2013-06-01              19.818                          0.344
# 8311  8585432 2013-07-01              21.343                          0.288
# 8312  8585433 2013-08-01              22.225                          0.454
#
#            City Country Latitude Longitude
# ...

# %%
tr_data_means.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8313 entries, 0 to 8312
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   index                          8313 non-null   int64
#  1   dt                             8313 non-null   datetime64[ns]
#  2   AverageTemperature             8313 non-null   float64
#  3   AverageTemperatureUncertainty  8313 non-null   float64
#  4   City                           8313 non-null   object
#  5   Country                        8313 non-null   object
#  6   Latitude                       8313 non-null   object
#  7   Longitude                      8313 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 519.7+ KB

# %%
tr_data_means["dt"].astype("datetime64")
# Out:
# 0      2000-02-01
# 1      2000-03-01
# 2      2000-04-01
# 3      2000-05-01
# 4      2000-06-01
#           ...
# 8308   2013-04-01
# 8309   2013-05-01
# 8310   2013-06-01
# 8311   2013-07-01
# 8312   2013-08-01
# Name: dt, Length: 8313, dtype: datetime64[ns]

# %%
tr_data_means["dt"].dtype
# Out:
# dtype('<M8[ns]')

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x="dt" , y="AverageTemperature" , data = tr_data_means)
# Out:
# <AxesSubplot:xlabel='dt', ylabel='AverageTemperature'>

# %%
dt_2000 = dt_selected[dt_selected["dt"]>"01.01.2000"]

# %%
dt_2000.head()
# Out:
#              dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 3075 2000-02-01               3.724                          0.241  Århus
# 3076 2000-03-01               3.976                          0.296  Århus
# 3077 2000-04-01               8.321                          0.221  Århus
# 3078 2000-05-01              13.567                          0.253  Århus
# 3079 2000-06-01              14.702                          0.240  Århus
#
#       Country Latitude Longitude
# 3075  Denmark   57.05N    10.33E
# 3076  Denmark   57.05N    10.33E
# 3077  Denmark   57.05N    10.33E
# 3078  Denmark   57.05N    10.33E
# 3079  Denmark   57.05N    10.33E

# %%
dt_mean = dt_2000.groupby(["Country",dt_2000["dt"].dt.to_period("Y")]).mean()

# %%
dt_means = dt_mean.reset_index()

# %%
dt_means["dt"] = dt_means["dt"].astype("string").astype("datetime64")

# %%
dt_means.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 4 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        42 non-null     object
#  1   dt                             42 non-null     datetime64[ns]
#  2   AverageTemperature             42 non-null     float64
#  3   AverageTemperatureUncertainty  42 non-null     float64
# dtypes: datetime64[ns](1), float64(2), object(1)
# memory usage: 1.4+ KB

# %%
for col in dt_means.columns[2:4]:
    plt.figure(figsize=(15,5))
    
    for ulke in dt_means["Country"].unique():
        data = dt_means[dt_means["Country"]==ulke]
        sns.lineplot(x="dt" , y = col , data = data)        
        plt.legend(dt_means["Country"].unique())

# %%
for col in dt_means.columns[2:4]:
    plt.figure(figsize=(15,5))
    for ulke in dt_means["Country"].unique():
        data = dt_means[dt_means["Country"]==ulke]
        sns.lineplot(x="dt" , y = col , data = data)
        plt.legend(dt_means["Country"].unique())
    plt.show()
