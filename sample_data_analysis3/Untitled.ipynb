# %%
import pandas as pd

# %%
dt = pd.read_csv("ca_san_diego_2019_02_25.csv")

# %%
dt.head()
# Out:
#    raw_row_number        date      time service_area  subject_age  \
# 0               1  2014-01-01  01:25:00          110         24.0
# 1               2  2014-01-01  05:47:00          320         42.0
# 2               3  2014-01-01  07:46:00          320         29.0
# 3               4  2014-01-01  08:10:00          610         23.0
# 4               5  2014-01-01  08:35:00          930         35.0
#
#              subject_race subject_sex       type arrest_made citation_issued  \
# 0                   white        male  vehicular       False            True
# 1                   white        male  vehicular       False           False
# 2  asian/pacific islander        male  vehicular       False           False
# 3                   white        male  vehicular       False            True
# 4                hispanic        male  vehicular       False            True
#
#   warning_issued   outcome contraband_found search_conducted search_person  \
# ...

# %%
dt.tail()
# Out:
#         raw_row_number        date      time service_area  subject_age  \
# 390994          390995  2017-03-31  23:45:00          830         20.0
# 390995          390996  2017-03-31  23:45:00          710         65.0
# 390996          390997  2017-03-31  23:49:00          620         23.0
# 390997          390998  2017-03-31  23:55:00          710          NaN
# 390998          390999  2017-03-31  23:58:00          310         26.0
#
#        subject_race subject_sex       type arrest_made citation_issued  \
# 390994        black        male  vehicular       False           False
# 390995     hispanic        male  vehicular         NaN            True
# 390996     hispanic        male  vehicular       False           False
# 390997     hispanic        male  vehicular         NaN            True
# 390998        white      female  vehicular         NaN           False
#
#        warning_issued   outcome contraband_found search_conducted  \
# ...

# %%
dt.shape
# Out:
# (390999, 21)

# %%
dt.dtypes
# Out:
# raw_row_number                int64
# date                         object
# time                         object
# service_area                 object
# subject_age                 float64
# subject_race                 object
# subject_sex                  object
# type                         object
# arrest_made                    bool
# citation_issued              object
# warning_issued               object
# outcome                      object
# contraband_found             object
# search_conducted             object
# search_person                object
# search_vehicle               object
# search_basis                 object
# reason_for_search            object
# reason_for_stop              object
# stop_date            datetime64[ns]
# stop_datetime        datetime64[ns]
# dtype: object

# %%
dt.isnull()
# Out:
#         raw_row_number   date   time  service_area  subject_age  subject_race  \
# 0                False  False  False         False        False         False
# 1                False  False  False         False        False         False
# 2                False  False  False         False        False         False
# 3                False  False  False         False        False         False
# 4                False  False  False         False        False         False
# ...                ...    ...    ...           ...          ...           ...
# 390994           False  False  False         False        False         False
# 390995           False  False  False         False        False         False
# 390996           False  False  False         False        False         False
# 390997           False  False  False         False         True         False
# 390998           False  False  False         False        False         False
#
# ...

# %%
dt.isnull().sum()
# Out:
# raw_row_number            0
# date                    132
# time                   1256
# service_area              0
# subject_age           12644
# subject_race           1398
# subject_sex             806
# type                      0
# arrest_made           35022
# citation_issued       32712
# warning_issued        32712
# outcome               40047
# contraband_found     379835
# search_conducted      37096
# search_person        376459
# search_vehicle       376459
# search_basis         374173
# reason_for_search    376343
# reason_for_stop         266
# dtype: int64

# %%
dt.date.head()
# Out:
# 0    2014-01-01
# 1    2014-01-01
# 2    2014-01-01
# 3    2014-01-01
# 4    2014-01-01
# Name: date, dtype: object

# %%
dt.columns
# Out:
# Index(['raw_row_number', 'date', 'time', 'service_area', 'subject_age',
#        'subject_race', 'subject_sex', 'type', 'arrest_made', 'citation_issued',
#        'warning_issued', 'outcome', 'contraband_found', 'search_conducted',
#        'search_person', 'search_vehicle', 'search_basis', 'reason_for_search',
#        'reason_for_stop', 'stop_date', 'stop_datetime'],
#       dtype='object')

# %%
dt.time.head()
# Out:
# 0    01:25:00
# 1    05:47:00
# 2    07:46:00
# 3    08:10:00
# 4    08:35:00
# Name: time, dtype: object

# %%
dt["time"].head()
# Out:
# 0    01:25:00
# 1    05:47:00
# 2    07:46:00
# 3    08:10:00
# 4    08:35:00
# Name: time, dtype: object

# %%
dt[["date","time"]].head()
# Out:
#          date      time
# 0  2014-01-01  01:25:00
# 1  2014-01-01  05:47:00
# 2  2014-01-01  07:46:00
# 3  2014-01-01  08:10:00
# 4  2014-01-01  08:35:00

# %%
dt.rename(columns = {"date":"tarih", "time":"zaman"}).head()
# Out:
#    raw_row_number       tarih     zaman service_area  subject_age  \
# 0               1  2014-01-01  01:25:00          110         24.0
# 1               2  2014-01-01  05:47:00          320         42.0
# 2               3  2014-01-01  07:46:00          320         29.0
# 3               4  2014-01-01  08:10:00          610         23.0
# 4               5  2014-01-01  08:35:00          930         35.0
#
#              subject_race subject_sex       type arrest_made citation_issued  \
# 0                   white        male  vehicular       False            True
# 1                   white        male  vehicular       False           False
# 2  asian/pacific islander        male  vehicular       False           False
# 3                   white        male  vehicular       False            True
# 4                hispanic        male  vehicular       False            True
#
#   warning_issued   outcome contraband_found search_conducted search_person  \
# ...

# %%
dt.head()
# Out:
#    raw_row_number        date      time service_area  subject_age  \
# 0               1  2014-01-01  01:25:00          110         24.0
# 1               2  2014-01-01  05:47:00          320         42.0
# 2               3  2014-01-01  07:46:00          320         29.0
# 3               4  2014-01-01  08:10:00          610         23.0
# 4               5  2014-01-01  08:35:00          930         35.0
#
#              subject_race subject_sex       type arrest_made citation_issued  \
# 0                   white        male  vehicular       False            True
# 1                   white        male  vehicular       False           False
# 2  asian/pacific islander        male  vehicular       False           False
# 3                   white        male  vehicular       False            True
# 4                hispanic        male  vehicular       False            True
#
#   warning_issued   outcome contraband_found search_conducted search_person  \
# ...

# %%
dt.rename(columns = {"date":"tarih" , "time":"zaman"} , inplace=True )

# %%
dt.head()
# Out:
#    raw_row_number       tarih     zaman service_area  subject_age  \
# 0               1  2014-01-01  01:25:00          110         24.0
# 1               2  2014-01-01  05:47:00          320         42.0
# 2               3  2014-01-01  07:46:00          320         29.0
# 3               4  2014-01-01  08:10:00          610         23.0
# 4               5  2014-01-01  08:35:00          930         35.0
#
#              subject_race subject_sex       type arrest_made citation_issued  \
# 0                   white        male  vehicular       False            True
# 1                   white        male  vehicular       False           False
# 2  asian/pacific islander        male  vehicular       False           False
# 3                   white        male  vehicular       False            True
# 4                hispanic        male  vehicular       False            True
#
#   warning_issued   outcome contraband_found search_conducted search_person  \
# ...

# %%
dt.iloc[0,0]
# Out:
# 1

# %%
dt.iloc[0 , [0,1,2,4]]
# Out:
# raw_row_number             1
# tarih             2014-01-01
# zaman               01:25:00
# subject_age               24
# Name: 0, dtype: object

# %%
dt.iloc[0:5 , [1,2,3]]
# Out:
#         tarih     zaman service_area
# 0  2014-01-01  01:25:00          110
# 1  2014-01-01  05:47:00          320
# 2  2014-01-01  07:46:00          320
# 3  2014-01-01  08:10:00          610
# 4  2014-01-01  08:35:00          930

# %%
dt.iloc[0:3,0:3]
# Out:
#    raw_row_number       tarih     zaman
# 0               1  2014-01-01  01:25:00
# 1               2  2014-01-01  05:47:00
# 2               3  2014-01-01  07:46:00

# %%
dt.loc[1 , "zaman"]
# Out:
# '05:47:00'

# %%
dt.loc[1:3 , "zaman":"subject_age"]
# Out:
#       zaman service_area  subject_age
# 1  05:47:00          320         42.0
# 2  07:46:00          320         29.0
# 3  08:10:00          610         23.0

# %% [markdown]
# #dropnada da kalıcı olarak etki edilmez. yine inplace kullanılmalı değişikliğin kalıcı olması için

# %%
dt.dropna(axis="columns" , how="all").shape
# Out:
# (390999, 19)

# %%
dt.shape
# Out:
# (390999, 19)

# %%
dt.dropna(axis="columns",how="any").shape
# Out:
# (390999, 3)

# %%
dt.shape
# Out:
# (390999, 19)

# %%
dt.reason_for_stop
# Out:
# 0                   Moving Violation
# 1                   Moving Violation
# 2                   Moving Violation
# 3                   Moving Violation
# 4                Equipment Violation
#                      ...
# 390994              Moving Violation
# 390995              Moving Violation
# 390996    Radio Call/Citizen Contact
# 390997              Moving Violation
# 390998           Equipment Violation
# Name: reason_for_stop, Length: 390999, dtype: object

# %%
dt.reason_for_stop.value_counts()
# Out:
# Moving Violation                      285562
# Equipment Violation                    99577
# Radio Call/Citizen Contact              1941
# Muni, County, H&S Code                  1349
# Personal Knowledge/Informant             884
# Suspect Info (I.S., Bulletin, Log)       539
# No Cause Specified on a Card             430
# Personal Observ/Knowledge                104
# Muni                                      85
# UNI, &County, H&&S Code                   73
# Other                                     39
# Suspect Info (I.S.                        39
# MUNI, County, H&S Code                    29
# &Moving Violation                         21
# Suspect Info                              17
# MUNI                                       8
# none listed                                6
# not marked                                 4
# &Equipment Violation                       3
# NOTHING MARKED                             2
# NOT MARKED                                 2
# ...

# %%
dt.head()
# Out:
#    raw_row_number       tarih     zaman service_area  subject_age  \
# 0               1  2014-01-01  01:25:00          110         24.0
# 1               2  2014-01-01  05:47:00          320         42.0
# 2               3  2014-01-01  07:46:00          320         29.0
# 3               4  2014-01-01  08:10:00          610         23.0
# 4               5  2014-01-01  08:35:00          930         35.0
#
#              subject_race subject_sex       type arrest_made citation_issued  \
# 0                   white        male  vehicular       False            True
# 1                   white        male  vehicular       False           False
# 2  asian/pacific islander        male  vehicular       False           False
# 3                   white        male  vehicular       False            True
# 4                hispanic        male  vehicular       False            True
#
#   warning_issued   outcome contraband_found search_conducted search_person  \
# ...

# %%
dt[dt.reason_for_stop == "Moving Violation"].subject_sex.value_counts()
# Out:
# male      179242
# female    105765
# Name: subject_sex, dtype: int64

# %%
dt[dt.reason_for_stop == "Moving Violation"].subject_sex.value_counts(normalize = True)
# Out:
# male      0.628904
# female    0.371096
# Name: subject_sex, dtype: float64

# %%
dt.groupby("subject_sex").reason_for_stop.value_counts(normalize=True)
# Out:
# subject_sex  reason_for_stop
# female       Moving Violation                      0.773651
#              Equipment Violation                   0.215736
#              Radio Call/Citizen Contact            0.003606
#              Muni, County, H&S Code                0.002516
#              Personal Knowledge/Informant          0.001609
#              No Cause Specified on a Card          0.001287
#              Suspect Info (I.S., Bulletin, Log)    0.000929
#              Personal Observ/Knowledge             0.000234
#              Other                                 0.000110
#              UNI, &County, H&&S Code               0.000110
#              &Moving Violation                     0.000044
#              Suspect Info                          0.000044
#              MUNI, County, H&S Code                0.000029
#              &Equipment Violation                  0.000015
#              NOT MARKED                            0.000015
# ...

# %%
dt.head()
# Out:
#    raw_row_number       tarih     zaman service_area  subject_age  \
# 0               1  2014-01-01  01:25:00          110         24.0
# 1               2  2014-01-01  05:47:00          320         42.0
# 2               3  2014-01-01  07:46:00          320         29.0
# 3               4  2014-01-01  08:10:00          610         23.0
# 4               5  2014-01-01  08:35:00          930         35.0
#
#              subject_race subject_sex       type arrest_made citation_issued  \
# 0                   white        male  vehicular       False            True
# 1                   white        male  vehicular       False           False
# 2  asian/pacific islander        male  vehicular       False           False
# 3                   white        male  vehicular       False            True
# 4                hispanic        male  vehicular       False            True
#
#   warning_issued   outcome contraband_found search_conducted search_person  \
# ...

# %%
dt.tarih.str.slice(0,4)
# Out:
# 0         2014
# 1         2014
# 2         2014
# 3         2014
# 4         2014
#           ...
# 390994    2017
# 390995    2017
# 390996    2017
# 390997    2017
# 390998    2017
# Name: tarih, Length: 390999, dtype: object

# %% [raw]
# #tarih ve zaman bileşenlerini birleştirmek

# %%
birles = dt.tarih.str.cat(dt.zaman , sep=" ")

# %%
dt["stop_datetime"] = pd.to_datetime(birles)

# %%
dt.head()
# Out:
#    raw_row_number        date      time service_area  subject_age  \
# 0               1  2014-01-01  01:25:00          110         24.0
# 1               2  2014-01-01  05:47:00          320         42.0
# 2               3  2014-01-01  07:46:00          320         29.0
# 3               4  2014-01-01  08:10:00          610         23.0
# 4               5  2014-01-01  08:35:00          930         35.0
#
#              subject_race subject_sex       type arrest_made citation_issued  \
# 0                   white        male  vehicular       False            True
# 1                   white        male  vehicular       False           False
# 2  asian/pacific islander        male  vehicular       False           False
# 3                   white        male  vehicular       False            True
# 4                hispanic        male  vehicular       False            True
#
#    ...   outcome contraband_found search_conducted search_person  \
# ...

# %%
dt.dtypes
# Out:
# raw_row_number                int64
# date                         object
# time                         object
# service_area                 object
# subject_age                 float64
# subject_race                 object
# subject_sex                  object
# type                         object
# arrest_made                  object
# citation_issued              object
# warning_issued               object
# outcome                      object
# contraband_found             object
# search_conducted             object
# search_person                object
# search_vehicle               object
# search_basis                 object
# reason_for_search            object
# reason_for_stop              object
# stop_date            datetime64[ns]
# stop_datetime        datetime64[ns]
# dtype: object

# %%
dt.stop_datetime.dt.year
# Out:
# 0         2014.0
# 1         2014.0
# 2         2014.0
# 3         2014.0
# 4         2014.0
#            ...
# 390994    2017.0
# 390995    2017.0
# 390996    2017.0
# 390997    2017.0
# 390998    2017.0
# Name: stop_datetime, Length: 390999, dtype: float64

# %%
dt.stop_datetime.dt.month
# Out:
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#          ...
# 390994    3.0
# 390995    3.0
# 390996    3.0
# 390997    3.0
# 390998    3.0
# Name: stop_datetime, Length: 390999, dtype: float64

# %% [markdown]
# #değişken tipi değiştirme

# %%
dt.dtypes
# Out:
# raw_row_number                int64
# date                         object
# time                         object
# service_area                 object
# subject_age                 float64
# subject_race                 object
# subject_sex                  object
# type                         object
# arrest_made                  object
# citation_issued              object
# warning_issued               object
# outcome                      object
# contraband_found             object
# search_conducted             object
# search_person                object
# search_vehicle               object
# search_basis                 object
# reason_for_search            object
# reason_for_stop              object
# stop_date            datetime64[ns]
# stop_datetime        datetime64[ns]
# dtype: object

# %%
dt["arrest_made"] = dt.arrest_made.astype(bool)

# %%
dt.dtypes
# Out:
# raw_row_number                int64
# date                         object
# time                         object
# service_area                 object
# subject_age                 float64
# subject_race                 object
# subject_sex                  object
# type                         object
# arrest_made                    bool
# citation_issued              object
# warning_issued               object
# outcome                      object
# contraband_found             object
# search_conducted             object
# search_person                object
# search_vehicle               object
# search_basis                 object
# reason_for_search            object
# reason_for_stop              object
# stop_date            datetime64[ns]
# stop_datetime        datetime64[ns]
# dtype: object

# %%
dt.arrest_made.value_counts()
# Out:
# False    351060
# True      39939
# Name: arrest_made, dtype: int64

# %%
dt.arrest_made.mean()
# Out:
# 0.10214604129422326

# %%
dt.groupby(dt.stop_datetime.dt.hour).arrest_made.mean()
# Out:
# stop_datetime
# 0.0     0.113073
# 1.0     0.140684
# 2.0     0.141698
# 3.0     0.127541
# 4.0     0.105165
# 5.0     0.063767
# 6.0     0.114924
# 7.0     0.075330
# 8.0     0.064346
# 9.0     0.061174
# 10.0    0.058614
# 11.0    0.078432
# 12.0    0.015655
# 13.0    0.053309
# 14.0    0.075281
# 15.0    0.132653
# 16.0    0.163263
# 17.0    0.171670
# 18.0    0.169753
# 19.0    0.139718
# 20.0    0.152607
# 21.0    0.125060
# 22.0    0.102684
# 23.0    0.105551
# Name: arrest_made, dtype: float64

# %%
# %matplotlib inline
dt.groupby(dt.stop_datetime.dt.hour).arrest_made.mean().plot()
# Out:
# <AxesSubplot:xlabel='stop_datetime'>
